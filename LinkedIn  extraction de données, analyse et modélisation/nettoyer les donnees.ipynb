# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('output_profile-FINAL1.csv', sep='\t')

# %% [markdown]
# # DataFrame Overview

# %%
df.head()
# Out:
#                                                 link  \
# 0     https://www.linkedin.com/in/abdelhamidtechtach
# 1  https://www.linkedin.com/in/abderrahmane-issam...
# 2  https://www.linkedin.com/in/souhail-bouketaya-...
# 3  https://www.linkedin.com/in/anass-allak-7660a5168
# 4  https://www.linkedin.com/in/haitam-foudil-2aba...
#
#                            localisation            D_Expérience  \
# 0  Casablanca, Casablanca-Settat, Maroc          Data Scientist
# 1             Rabat-Salé-Kénitra, Maroc          Data Scientist
# 2              Casablanca-Settat, Maroc          Data Scientist
# 3  Casablanca, Casablanca-Settat, Maroc          Data scientist
# 4              Casablanca et périphérie  Researcher PhD Student
#
#   Type_Expérienc                 Nom_de_entreprise           Dates_d_emploi  \
# 0       employee  Observatoire Marocain de la TPME  nov. 2021 – Aujourd’hui
# 1    Temps plein                Archipel-cognitive  nov. 2021 – Aujourd’hui
# ...

# %% [markdown]
# # modifier l'en-tête DataFrame

# %%
headerList = ['profile', 'loc', 'exp_title', 'type_experience', 'exp_company', 'exp_dates', 'loc_company', 'exp_numbre', 'school_name', 'ed_deg', 'ed_title', 'ed_date', 'skills' ]

# %%
df.to_csv("linkdelin_profile.csv",sep='\t', header=headerList, index=False)

# %%
df2 = pd.read_csv('linkdelin_profile.csv', sep='\t')

# %% [markdown]
# # Vue d'ensemble de données après le modification

# %%
df2.head()
# Out:
#                                              profile  \
# 0     https://www.linkedin.com/in/abdelhamidtechtach
# 1  https://www.linkedin.com/in/abderrahmane-issam...
# 2  https://www.linkedin.com/in/souhail-bouketaya-...
# 3  https://www.linkedin.com/in/anass-allak-7660a5168
# 4  https://www.linkedin.com/in/haitam-foudil-2aba...
#
#                                     loc               exp_title  \
# 0  Casablanca, Casablanca-Settat, Maroc          Data Scientist
# 1             Rabat-Salé-Kénitra, Maroc          Data Scientist
# 2              Casablanca-Settat, Maroc          Data Scientist
# 3  Casablanca, Casablanca-Settat, Maroc          Data scientist
# 4              Casablanca et périphérie  Researcher PhD Student
#
#   type_experience                       exp_company                exp_dates  \
# 0        employee  Observatoire Marocain de la TPME  nov. 2021 – Aujourd’hui
# 1     Temps plein                Archipel-cognitive  nov. 2021 – Aujourd’hui
# ...

# %%
df2.shape
# Out:
# (2257, 13)

# %%
df2.columns
# Out:
# Index(['profile', 'loc', 'exp_title', 'type_experience', 'exp_company',
#        'exp_dates', 'loc_company', 'exp_numbre', 'school_name', 'ed_deg',
#        'ed_title', 'ed_date', 'skills'],
#       dtype='object')

# %%
df2.profile
# Out:
# 0          https://www.linkedin.com/in/abdelhamidtechtach
# 1       https://www.linkedin.com/in/abderrahmane-issam...
# 2       https://www.linkedin.com/in/souhail-bouketaya-...
# 3       https://www.linkedin.com/in/anass-allak-7660a5168
# 4       https://www.linkedin.com/in/haitam-foudil-2aba...
#                               ...
# 2252    https://www.linkedin.com/in/ayoub-zekhnini-18a...
# 2253    https://www.linkedin.com/in/abdoulkarim-boubac...
# 2254    https://www.linkedin.com/in/nora-rahman-378298102
# 2255    https://www.linkedin.com/in/rahmani-taoufiq-da...
# 2256    https://www.linkedin.com/in/omar-ouakkad-81425...
# Name: profile, Length: 2257, dtype: object

# %%
profile=set(df2.profile)

# %% [markdown]
# ### Traitement des valeurs dupliquées

# %%
profile
# Out:
# {'https://www.linkedin.com/in/fatima-ezzahra-jarmouni',
#  'https://www.linkedin.com/in/siham-eddamiri-56b98aab',
#  'https://www.linkedin.com/in/hassan-mezoir',
#  'https://www.linkedin.com/in/abdrahman-hilal',
#  'https://www.linkedin.com/in/karim-majdi-3a4960197',
#  'https://www.linkedin.com/in/lamia-eddahmouni-77b60765',
#  'https://www.linkedin.com/in/youssefabiza',
#  'https://www.linkedin.com/in/ayoubhoummani',
#  'https://www.linkedin.com/in/mohamed-rdait-259231194',
#  'https://www.linkedin.com/in/souhail-bouketaya-718587148',
#  'https://www.linkedin.com/in/imane-chlioui-590976a5',
#  'https://www.linkedin.com/in/yassine-houmaid-55b13a115',
#  'https://www.linkedin.com/in/basma-karbal-029650141',
#  'https://www.linkedin.com/in/hamza-abbaoui-00b28465',
#  'https://www.linkedin.com/in/anass-garbaz-33515817a',
#  'https://www.linkedin.com/in/manamemohamed13',
#  'https://www.linkedin.com/in/hamza-douaioui-28868b218',
#  'https://www.linkedin.com/in/ayoub-sghir-99b696138',
# ...

# %%
len(profile)
# Out:
# 1631

# %%
df2.drop_duplicates(subset ="profile", keep = False, inplace = True)

# %%
df2
# Out:
#                                                 profile  \
# 278          https://www.linkedin.com/in/fatima-laachir
# 282   https://www.linkedin.com/in/sara-hajjouj-85a70...
# 284   https://www.linkedin.com/in/loubna-rabhi-70857762
# 285           https://www.linkedin.com/in/ayyoub-frifra
# 286          https://www.linkedin.com/in/ismailgadraoui
# ...                                                 ...
# 2249  https://www.linkedin.com/in/mehdi-abouhane-a42...
# 2251  https://www.linkedin.com/in/souad-abakarim-359...
# 2252  https://www.linkedin.com/in/ayoub-zekhnini-18a...
# 2253  https://www.linkedin.com/in/abdoulkarim-boubac...
# 2256  https://www.linkedin.com/in/omar-ouakkad-81425...
#
#                                        loc  \
# 278   Casablanca, Casablanca-Settat, Maroc
# 282                                  Maroc
# 284                                  Maroc
# 285               Casablanca-Settat, Maroc
# 286       Marrakech, Marrakesh-Safi, Maroc
# ...

# %%
df2.to_csv("exp2.csv",sep='\t', index=False)

# %%
df3 = pd.read_csv('exp2.csv', sep='\t')

# %%
profile3=set(df3.profile)

# %%
len(profile3)
# Out:
# 1153

# %%
print(df3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1153 entries, 0 to 1152
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   profile          1153 non-null   object
#  1   loc              1153 non-null   object
#  2   exp_title        1145 non-null   object
#  3   type_experience  1153 non-null   object
#  4   exp_company      984 non-null    object
#  5   exp_dates        1153 non-null   object
#  6   loc_company      971 non-null    object
#  7   exp_numbre       1153 non-null   int64
#  8   school_name      1153 non-null   object
#  9   ed_deg           1153 non-null   object
#  10  ed_title         1153 non-null   object
#  11  ed_date          1153 non-null   int64
#  12  skills           1086 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 117.2+ KB
# None

# %%
df3
# Out:
#                                                 profile  \
# 0            https://www.linkedin.com/in/fatima-laachir
# 1     https://www.linkedin.com/in/sara-hajjouj-85a70...
# 2     https://www.linkedin.com/in/loubna-rabhi-70857762
# 3             https://www.linkedin.com/in/ayyoub-frifra
# 4            https://www.linkedin.com/in/ismailgadraoui
# ...                                                 ...
# 1148  https://www.linkedin.com/in/mehdi-abouhane-a42...
# 1149  https://www.linkedin.com/in/souad-abakarim-359...
# 1150  https://www.linkedin.com/in/ayoub-zekhnini-18a...
# 1151  https://www.linkedin.com/in/abdoulkarim-boubac...
# 1152  https://www.linkedin.com/in/omar-ouakkad-81425...
#
#                                        loc  \
# 0     Casablanca, Casablanca-Settat, Maroc
# 1                                    Maroc
# 2                                    Maroc
# 3                 Casablanca-Settat, Maroc
# 4         Marrakech, Marrakesh-Safi, Maroc
# ...

# %% [markdown]
# ### Traitement des valeurs manquantes

# %%
print(df3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1153 entries, 0 to 1152
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   profile          1153 non-null   object
#  1   loc              1153 non-null   object
#  2   exp_title        1153 non-null   object
#  3   type_experience  1153 non-null   object
#  4   exp_company      984 non-null    object
#  5   exp_dates        1153 non-null   object
#  6   loc_company      971 non-null    object
#  7   exp_numbre       1153 non-null   int64
#  8   school_name      1153 non-null   object
#  9   ed_deg           1153 non-null   object
#  10  ed_title         1153 non-null   object
#  11  ed_date          1153 non-null   int64
#  12  skills           1086 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 126.1+ KB
# None

# %% [markdown]
# # remplacement le valeur nulle

# %%
df3["exp_company"].fillna("unknown company", inplace = True)

# %% [markdown]
# # remplacement le valeur nulle

# %%
df3["loc_company"].fillna("Maroc", inplace = True)

# %% [markdown]
# # remplacement le valeur nulle

# %%
mylist2 = ["python", "R", "Machine Learning"]

# %%
mylist2
# Out:
# ['python', 'R', 'Machine Learning']

# %%
import random
df3["skills"].fillna(random.choice(mylist2), inplace = True)

# %%
df3
# Out:
#                                                 profile  \
# 0            https://www.linkedin.com/in/fatima-laachir
# 1     https://www.linkedin.com/in/sara-hajjouj-85a70...
# 2     https://www.linkedin.com/in/loubna-rabhi-70857762
# 3             https://www.linkedin.com/in/ayyoub-frifra
# 4            https://www.linkedin.com/in/ismailgadraoui
# ...                                                 ...
# 1148  https://www.linkedin.com/in/mehdi-abouhane-a42...
# 1149  https://www.linkedin.com/in/souad-abakarim-359...
# 1150  https://www.linkedin.com/in/ayoub-zekhnini-18a...
# 1151  https://www.linkedin.com/in/abdoulkarim-boubac...
# 1152  https://www.linkedin.com/in/omar-ouakkad-81425...
#
#                                        loc  \
# 0     Casablanca, Casablanca-Settat, Maroc
# 1                                    Maroc
# 2                                    Maroc
# 3                 Casablanca-Settat, Maroc
# 4         Marrakech, Marrakesh-Safi, Maroc
# ...

# %% [markdown]
# # Vue d'ensemble de données après le modification

# %%
print(df3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1153 entries, 0 to 1152
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   profile          1153 non-null   object
#  1   loc              1153 non-null   object
#  2   exp_title        1153 non-null   object
#  3   type_experience  1153 non-null   object
#  4   exp_company      1153 non-null   object
#  5   exp_dates        1153 non-null   object
#  6   loc_company      1153 non-null   object
#  7   exp_numbre       1153 non-null   int64
#  8   school_name      1153 non-null   object
#  9   ed_deg           1153 non-null   object
#  10  ed_title         1153 non-null   object
#  11  ed_date          1153 non-null   int64
#  12  skills           1153 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 126.1+ KB
# None

# %%
df3.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=[" "," "], regex=True, inplace=True)

# %%
df3
# Out:
#                                                 profile  \
# 0            https://www.linkedin.com/in/fatima-laachir
# 1     https://www.linkedin.com/in/sara-hajjouj-85a70...
# 2     https://www.linkedin.com/in/loubna-rabhi-70857762
# 3             https://www.linkedin.com/in/ayyoub-frifra
# 4            https://www.linkedin.com/in/ismailgadraoui
# ...                                                 ...
# 1148  https://www.linkedin.com/in/mehdi-abouhane-a42...
# 1149  https://www.linkedin.com/in/souad-abakarim-359...
# 1150  https://www.linkedin.com/in/ayoub-zekhnini-18a...
# 1151  https://www.linkedin.com/in/abdoulkarim-boubac...
# 1152  https://www.linkedin.com/in/omar-ouakkad-81425...
#
#                                        loc  \
# 0     Casablanca, Casablanca-Settat, Maroc
# 1                                    Maroc
# 2                                    Maroc
# 3                 Casablanca-Settat, Maroc
# 4         Marrakech, Marrakesh-Safi, Maroc
# ...

# %%
print(df3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1153 entries, 0 to 1152
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   profile          1153 non-null   object
#  1   loc              1153 non-null   object
#  2   exp_title        1153 non-null   object
#  3   type_experience  1153 non-null   object
#  4   exp_company      1153 non-null   object
#  5   exp_dates        1153 non-null   object
#  6   loc_company      1153 non-null   object
#  7   exp_numbre       1153 non-null   int64
#  8   school_name      1153 non-null   object
#  9   ed_deg           1153 non-null   object
#  10  ed_title         1153 non-null   object
#  11  ed_date          1153 non-null   int64
#  12  skills           1153 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 126.1+ KB
# None

# %%
df4 = df3.applymap(lambda s: s.lower() if type(s) == str else s)

# %%
df4
# Out:
#                                                 profile  \
# 0            https://www.linkedin.com/in/fatima-laachir
# 1     https://www.linkedin.com/in/sara-hajjouj-85a70...
# 2     https://www.linkedin.com/in/loubna-rabhi-70857762
# 3             https://www.linkedin.com/in/ayyoub-frifra
# 4            https://www.linkedin.com/in/ismailgadraoui
# ...                                                 ...
# 1148  https://www.linkedin.com/in/mehdi-abouhane-a42...
# 1149  https://www.linkedin.com/in/souad-abakarim-359...
# 1150  https://www.linkedin.com/in/ayoub-zekhnini-18a...
# 1151  https://www.linkedin.com/in/abdoulkarim-boubac...
# 1152  https://www.linkedin.com/in/omar-ouakkad-81425...
#
#                                        loc  \
# 0     casablanca, casablanca-settat, maroc
# 1                                    maroc
# 2                                    maroc
# 3                 casablanca-settat, maroc
# 4         marrakech, marrakesh-safi, maroc
# ...

# %%
df4=df4.replace("maroc", "morocco", regex=True)
df4.to_csv("linkdelin_profile_vf.csv",sep='\t', header=headerList, index=False)
df4
# Out:
#                                                 profile  \
# 0            https://www.linkedin.com/in/fatima-laachir
# 1     https://www.linkedin.com/in/sara-hajjouj-85a70...
# 2     https://www.linkedin.com/in/loubna-rabhi-70857762
# 3             https://www.linkedin.com/in/ayyoub-frifra
# 4            https://www.linkedin.com/in/ismailgadraoui
# ...                                                 ...
# 1148  https://www.linkedin.com/in/mehdi-abouhane-a42...
# 1149  https://www.linkedin.com/in/souad-abakarim-359...
# 1150  https://www.linkedin.com/in/ayoub-zekhnini-18a...
# 1151  https://www.linkedin.com/in/abdoulkarim-boubac...
# 1152  https://www.linkedin.com/in/omar-ouakkad-81425...
#
#                                          loc  \
# 0     casablanca, casablanca-settat, morocco
# 1                                    morocco
# 2                                    morocco
# 3                 casablanca-settat, morocco
# 4         marrakech, marrakesh-safi, morocco
# ...
